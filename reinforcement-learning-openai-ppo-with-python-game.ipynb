# %% [markdown]
# # Lux AI Deep Reinforcement Learning Environment Example
# See https://github.com/glmcdona/LuxPythonEnvGym for environment project and updates.
#
# This is a python replica of the Lux game engine to speed up training. It reformats the agent problem into making a action decision per-unit for the team.

# %%
# !pip install git+https://github.com/glmcdona/LuxPythonEnvGym.git
# !pip install kaggle-environments -U
# Out:
# Collecting git+https://github.com/glmcdona/LuxPythonEnvGym.git
#   Cloning https://github.com/glmcdona/LuxPythonEnvGym.git to /tmp/pip-req-build-jiltard8
#   Running command git clone -q https://github.com/glmcdona/LuxPythonEnvGym.git /tmp/pip-req-build-jiltard8
# Requirement already satisfied: pytest in /opt/conda/lib/python3.7/site-packages (from luxai2021==0.1.0) (6.2.4)
# Collecting stable_baselines3
#   Downloading stable_baselines3-1.2.0-py3-none-any.whl (161 kB)
#      |████████████████████████████████| 161 kB 725 kB/s
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from luxai2021==0.1.0) (1.19.5)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.7/site-packages (from luxai2021==0.1.0) (2.4.1)
# Requirement already satisfied: gym in /opt/conda/lib/python3.7/site-packages (from luxai2021==0.1.0) (0.18.3)
# Requirement already satisfied: pyglet<=1.5.15,>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from gym->luxai2021==0.1.0) (1.5.15)
# Requirement already satisfied: Pillow<=8.2.0 in /opt/conda/lib/python3.7/site-packages (from gym->luxai2021==0.1.0) (8.2.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from gym->luxai2021==0.1.0) (1.6.3)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from gym->luxai2021==0.1.0) (1.6.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (20.9)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (1.1.1)
# Requirement already satisfied: toml in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (0.10.2)
# Requirement already satisfied: importlib-metadata>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (3.4.0)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (1.10.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (21.2.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->luxai2021==0.1.0) (0.13.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->luxai2021==0.1.0) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->luxai2021==0.1.0) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->pytest->luxai2021==0.1.0) (2.4.7)
# Collecting torch>=1.8.1
#   Downloading torch-1.9.1-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 3.8 kB/s
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from stable_baselines3->luxai2021==0.1.0) (3.4.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from stable_baselines3->luxai2021==0.1.0) (1.2.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3->luxai2021==0.1.0) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3->luxai2021==0.1.0) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->stable_baselines3->luxai2021==0.1.0) (0.10.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->stable_baselines3->luxai2021==0.1.0) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->stable_baselines3->luxai2021==0.1.0) (2021.1)
# Requirement already satisfied: protobuf>=3.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (3.17.3)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (0.36.2)
# Requirement already satisfied: grpcio>=1.24.3 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (1.32.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (49.6.0.post20210108)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (1.30.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (1.8.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (0.12.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (2.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard->luxai2021==0.1.0) (2.25.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard->luxai2021==0.1.0) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard->luxai2021==0.1.0) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard->luxai2021==0.1.0) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->luxai2021==0.1.0) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard->luxai2021==0.1.0) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->luxai2021==0.1.0) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->luxai2021==0.1.0) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->luxai2021==0.1.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard->luxai2021==0.1.0) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->luxai2021==0.1.0) (3.1.1)
# Building wheels for collected packages: luxai2021
# done
#   Created wheel for luxai2021: filename=luxai2021-0.1.0-py3-none-any.whl size=39158 sha256=63a3e6d2b23166e1e13082266a7b9dc44e6a6483526e850ce3d69defd6d6d34b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pieh5q1j/wheels/b2/22/ee/884dd4091817cdc45e2980f439823344fb99cad2a54fa05e65
# Successfully built luxai2021
# Installing collected packages: torch, stable-baselines3, luxai2021
#   Attempting uninstall: torch
#     Found existing installation: torch 1.7.0
#     Uninstalling torch-1.7.0:
#       Successfully uninstalled torch-1.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kornia 0.5.5 requires numpy<=1.19, but you have numpy 1.19.5 which is incompatible.
# fastai 2.2.7 requires torch<1.8,>=1.7.0, but you have torch 1.9.1 which is incompatible.
# allennlp 2.5.0 requires torch<1.9.0,>=1.6.0, but you have torch 1.9.1 which is incompatible.
# Successfully installed luxai2021-0.1.0 stable-baselines3-1.2.0 torch-1.9.1
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Requirement already satisfied: kaggle-environments in /opt/conda/lib/python3.7/site-packages (1.7.11)
# Collecting kaggle-environments
#   Downloading kaggle_environments-1.8.12-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 706 kB/s
# Requirement already satisfied: jsonschema>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from kaggle-environments) (3.2.0)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (1.15.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (49.6.0.post20210108)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (0.17.3)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0.1->kaggle-environments) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->jsonschema>=3.0.1->kaggle-environments) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->jsonschema>=3.0.1->kaggle-environments) (3.4.1)
# Installing collected packages: kaggle-environments
#   Attempting uninstall: kaggle-environments
#     Found existing installation: kaggle-environments 1.7.11
#     Uninstalling kaggle-environments-1.7.11:
#       Successfully uninstalled kaggle-environments-1.7.11
# Successfully installed kaggle-environments-1.8.12
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %% [markdown]
# ## Use GPU if available
# Note: GPU provides very little speedup. I recommend using a CPU-only notebook usually.

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
print(device)
# Out:
# cuda

# %% [markdown]
# # Define the RL agent logic
# Edit this agent logic to implement your own observations, action space, and reward shaping.

# %%
# %%writefile agent_policy.py
from luxai2021.game.match_controller import ActionSequence
import sys
import time
from functools import partial  # pip install functools

import numpy as np
from gym import spaces
import copy
import random

from luxai2021.env.agent import Agent
from luxai2021.game.actions import *
from luxai2021.game.game_constants import GAME_CONSTANTS
from luxai2021.game.position import Position


# https://codereview.stackexchange.com/questions/28207/finding-the-closest-point-to-a-list-of-points
def closest_node(node, nodes):
    dist_2 = np.sum((nodes - node) ** 2, axis=1)
    return np.argmin(dist_2)
def furthest_node(node, nodes):
    dist_2 = np.sum((nodes - node) ** 2, axis=1)
    return np.argmax(dist_2)

def smart_transfer_to_nearby(game, team, unit_id, unit, target_type_restriction=None, **kwarg):
    """
    Smart-transfers from the specified unit to a nearby neighbor. Prioritizes any
    nearby carts first, then any worker. Transfers the resource type which the unit
    has most of. Picks which cart/worker based on choosing a target that is most-full
    but able to take the most amount of resources.

    Args:
        team ([type]): [description]
        unit_id ([type]): [description]

    Returns:
        Action: Returns a TransferAction object, even if the request is an invalid
                transfer. Use TransferAction.is_valid() to check validity.
    """

    # Calculate how much resources could at-most be transferred
    resource_type = None
    resource_amount = 0
    target_unit = None

    if unit != None:
        for type, amount in unit.cargo.items():
            if amount > resource_amount:
                resource_type = type
                resource_amount = amount

        # Find the best nearby unit to transfer to
        unit_cell = game.map.get_cell_by_pos(unit.pos)
        adjacent_cells = game.map.get_adjacent_cells(unit_cell)

        
        for c in adjacent_cells:
            for id, u in c.units.items():
                # Apply the unit type target restriction
                if target_type_restriction == None or u.type == target_type_restriction:
                    if u.team == team:
                        # This unit belongs to our team, set it as the winning transfer target
                        # if it's the best match.
                        if target_unit is None:
                            target_unit = u
                        else:
                            # Compare this unit to the existing target
                            if target_unit.type == u.type:
                                # Transfer to the target with the least capacity, but can accept
                                # all of our resources
                                if( u.get_cargo_space_left() >= resource_amount and 
                                    target_unit.get_cargo_space_left() >= resource_amount ):
                                    # Both units can accept all our resources. Prioritize one that is most-full.
                                    if u.get_cargo_space_left() < target_unit.get_cargo_space_left():
                                        # This new target it better, it has less space left and can take all our
                                        # resources
                                        target_unit = u
                                    
                                elif( target_unit.get_cargo_space_left() >= resource_amount ):
                                    # Don't change targets. Current one is best since it can take all
                                    # the resources, but new target can't.
                                    pass
                                    
                                elif( u.get_cargo_space_left() > target_unit.get_cargo_space_left() ):
                                    # Change targets, because neither target can accept all our resources and 
                                    # this target can take more resources.
                                    target_unit = u
                            elif u.type == Constants.UNIT_TYPES.CART:
                                # Transfer to this cart instead of the current worker target
                                target_unit = u
    
    # Build the transfer action request
    target_unit_id = None
    if target_unit is not None:
        target_unit_id = target_unit.id

        # Update the transfer amount based on the room of the target
        if target_unit.get_cargo_space_left() < resource_amount:
            resource_amount = target_unit.get_cargo_space_left()
    
    return TransferAction(team, unit_id, target_unit_id, resource_type, resource_amount)

########################################################################################################################
# This is the Agent that you need to design for the competition
########################################################################################################################
class AgentPolicy(Agent):
    def __init__(self, mode="train", model=None) -> None:
        """
        Arguments:
            mode: "train" or "inference", which controls if this agent is for training or not.
            model: The pretrained model, or if None it will operate in training mode.
        """
        super().__init__()
        self.model = model
        self.mode = mode
        
        self.stats = None
        self.stats_last_game = None

        # Define action and observation space
        # They must be gym.spaces objects
        # Example when using discrete actions:
        self.actionSpaceMapUnits = [
            partial(MoveAction, direction=Constants.DIRECTIONS.CENTER),  # This is the do-nothing action
            partial(MoveAction, direction=Constants.DIRECTIONS.NORTH),
            partial(MoveAction, direction=Constants.DIRECTIONS.WEST),
            partial(MoveAction, direction=Constants.DIRECTIONS.SOUTH),
            partial(MoveAction, direction=Constants.DIRECTIONS.EAST),
            smart_transfer_to_nearby, # Transfer to nearby
            SpawnCityAction,
            #PillageAction,
        ]
        self.actionSpaceMapCities = [
            SpawnWorkerAction,
            SpawnCartAction,
            ResearchAction,
        ]

        self.action_space = spaces.Discrete(max(len(self.actionSpaceMapUnits), len(self.actionSpaceMapCities)))
        

        # Observation space: (Basic minimum for a miner agent)
        # Object:
        #   1x is worker
        #   1x is cart
        #   1x is citytile
        #
        #   5x direction_nearest_wood
        #   1x distance_nearest_wood
        #   1x amount
        #
        #   5x direction_nearest_coal
        #   1x distance_nearest_coal
        #   1x amount
        #
        #   5x direction_nearest_uranium
        #   1x distance_nearest_uranium
        #   1x amount
        #
        #   5x direction_nearest_city
        #   1x distance_nearest_city
        #   1x amount of fuel
        #
        #   28x (the same as above, but direction, distance, and amount to the furthest of each)
        #
        #   5x direction_nearest_worker
        #   1x distance_nearest_worker
        #   1x amount of cargo
        # Unit:
        #   1x cargo size
        # State:
        #   1x is night
        #   1x percent of game done
        #   2x citytile counts [cur player, opponent]
        #   2x worker counts [cur player, opponent]
        #   2x cart counts [cur player, opponent]
        #   1x research points [cur player]
        #   1x researched coal [cur player]
        #   1x researched uranium [cur player]
        self.observation_shape = (3 + 7 * 5 * 2 + 1 + 1 + 1 + 2 + 2 + 2 + 3,)
        self.observation_space = spaces.Box(low=0, high=1, shape=
        self.observation_shape, dtype=np.float16)

        self.object_nodes = {}

    def get_agent_type(self):
        """
        Returns the type of agent. Use AGENT for inference, and LEARNING for training a model.
        """
        if self.mode == "train":
            return Constants.AGENT_TYPE.LEARNING
        else:
            return Constants.AGENT_TYPE.AGENT

    def get_observation(self, game, unit, city_tile, team, is_new_turn):
        """
        Implements getting a observation from the current game for this unit or city
        """
        observation_index = 0
        if is_new_turn:
            # It's a new turn this event. This flag is set True for only the first observation from each turn.
            # Update any per-turn fixed observation space that doesn't change per unit/city controlled.

            # Build a list of object nodes by type for quick distance-searches
            self.object_nodes = {}

            # Add resources
            for cell in game.map.resources:
                if cell.resource.type not in self.object_nodes:
                    self.object_nodes[cell.resource.type] = np.array([[cell.pos.x, cell.pos.y]])
                else:
                    self.object_nodes[cell.resource.type] = np.concatenate(
                        (
                            self.object_nodes[cell.resource.type],
                            [[cell.pos.x, cell.pos.y]]
                        ),
                        axis=0
                    )

            # Add your own and opponent units
            for t in [team, (team + 1) % 2]:
                for u in game.state["teamStates"][team]["units"].values():
                    key = str(u.type)
                    if t != team:
                        key = str(u.type) + "_opponent"

                    if key not in self.object_nodes:
                        self.object_nodes[key] = np.array([[u.pos.x, u.pos.y]])
                    else:
                        self.object_nodes[key] = np.concatenate(
                            (
                                self.object_nodes[key],
                                [[u.pos.x, u.pos.y]]
                            )
                            , axis=0
                        )

            # Add your own and opponent cities
            for city in game.cities.values():
                for cells in city.city_cells:
                    key = "city"
                    if city.team != team:
                        key = "city_opponent"

                    if key not in self.object_nodes:
                        self.object_nodes[key] = np.array([[cells.pos.x, cells.pos.y]])
                    else:
                        self.object_nodes[key] = np.concatenate(
                            (
                                self.object_nodes[key],
                                [[cells.pos.x, cells.pos.y]]
                            )
                            , axis=0
                        )

        # Observation space: (Basic minimum for a miner agent)
        # Object:
        #   1x is worker
        #   1x is cart
        #   1x is citytile
        #   5x direction_nearest_wood
        #   1x distance_nearest_wood
        #   1x amount
        #
        #   5x direction_nearest_coal
        #   1x distance_nearest_coal
        #   1x amount
        #
        #   5x direction_nearest_uranium
        #   1x distance_nearest_uranium
        #   1x amount
        #
        #   5x direction_nearest_city
        #   1x distance_nearest_city
        #   1x amount of fuel
        #
        #   5x direction_nearest_worker
        #   1x distance_nearest_worker
        #   1x amount of cargo
        #
        #   28x (the same as above, but direction, distance, and amount to the furthest of each)
        #
        # Unit:
        #   1x cargo size
        # State:
        #   1x is night
        #   1x percent of game done
        #   2x citytile counts [cur player, opponent]
        #   2x worker counts [cur player, opponent]
        #   2x cart counts [cur player, opponent]
        #   1x research points [cur player]
        #   1x researched coal [cur player]
        #   1x researched uranium [cur player]
        obs = np.zeros(self.observation_shape)
        
        # Update the type of this object
        #   1x is worker
        #   1x is cart
        #   1x is citytile
        observation_index = 0
        if unit is not None:
            if unit.type == Constants.UNIT_TYPES.WORKER:
                obs[observation_index] = 1.0 # Worker
            else:
                obs[observation_index+1] = 1.0 # Cart
        if city_tile is not None:
            obs[observation_index+2] = 1.0 # CityTile
        observation_index += 3
        
        pos = None
        if unit is not None:
            pos = unit.pos
        else:
            pos = city_tile.pos

        if pos is None:
            observation_index += 7 * 5 * 2
        else:
            # Encode the direction to the nearest objects
            #   5x direction_nearest
            #   1x distance
            for distance_function in [closest_node, furthest_node]:
                for key in [
                    Constants.RESOURCE_TYPES.WOOD,
                    Constants.RESOURCE_TYPES.COAL,
                    Constants.RESOURCE_TYPES.URANIUM,
                    "city",
                    str(Constants.UNIT_TYPES.WORKER)]:
                    # Process the direction to and distance to this object type

                    # Encode the direction to the nearest object (excluding itself)
                    #   5x direction
                    #   1x distance
                    if key in self.object_nodes:
                        if (
                                (key == "city" and city_tile is not None) or
                                (unit is not None and str(unit.type) == key and len(game.map.get_cell_by_pos(unit.pos).units) <= 1 )
                        ):
                            # Filter out the current unit from the closest-search
                            closest_index = closest_node((pos.x, pos.y), self.object_nodes[key])
                            filtered_nodes = np.delete(self.object_nodes[key], closest_index, axis=0)
                        else:
                            filtered_nodes = self.object_nodes[key]

                        if len(filtered_nodes) == 0:
                            # No other object of this type
                            obs[observation_index + 5] = 1.0
                        else:
                            # There is another object of this type
                            closest_index = distance_function((pos.x, pos.y), filtered_nodes)

                            if closest_index is not None and closest_index >= 0:
                                closest = filtered_nodes[closest_index]
                                closest_position = Position(closest[0], closest[1])
                                direction = pos.direction_to(closest_position)
                                mapping = {
                                    Constants.DIRECTIONS.CENTER: 0,
                                    Constants.DIRECTIONS.NORTH: 1,
                                    Constants.DIRECTIONS.WEST: 2,
                                    Constants.DIRECTIONS.SOUTH: 3,
                                    Constants.DIRECTIONS.EAST: 4,
                                }
                                obs[observation_index + mapping[direction]] = 1.0  # One-hot encoding direction

                                # 0 to 1 distance
                                distance = pos.distance_to(closest_position)
                                obs[observation_index + 5] = min(distance / 20.0, 1.0)

                                # 0 to 1 value (amount of resource, cargo for unit, or fuel for city)
                                if key == "city":
                                    # City fuel as % of upkeep for 200 turns
                                    c = game.cities[game.map.get_cell_by_pos(closest_position).city_tile.city_id]
                                    obs[observation_index + 6] = min(
                                        c.fuel / (c.get_light_upkeep() * 200.0),
                                        1.0
                                    )
                                elif key in [Constants.RESOURCE_TYPES.WOOD, Constants.RESOURCE_TYPES.COAL,
                                             Constants.RESOURCE_TYPES.URANIUM]:
                                    # Resource amount
                                    obs[observation_index + 6] = min(
                                        game.map.get_cell_by_pos(closest_position).resource.amount / 500,
                                        1.0
                                    )
                                else:
                                    # Unit cargo
                                    obs[observation_index + 6] = min(
                                        next(iter(game.map.get_cell_by_pos(
                                            closest_position).units.values())).get_cargo_space_left() / 100,
                                        1.0
                                    )

                    observation_index += 7

        if unit is not None:
            # Encode the cargo space
            #   1x cargo size
            obs[observation_index] = unit.get_cargo_space_left() / GAME_CONSTANTS["PARAMETERS"]["RESOURCE_CAPACITY"][
                "WORKER"]
            observation_index += 1
        else:
            observation_index += 1

        # Game state observations

        #   1x is night
        obs[observation_index] = game.is_night()
        observation_index += 1

        #   1x percent of game done
        obs[observation_index] = game.state["turn"] / GAME_CONSTANTS["PARAMETERS"]["MAX_DAYS"]
        observation_index += 1

        #   2x citytile counts [cur player, opponent]
        #   2x worker counts [cur player, opponent]
        #   2x cart counts [cur player, opponent]
        max_count = 30
        for key in ["city", str(Constants.UNIT_TYPES.WORKER), str(Constants.UNIT_TYPES.CART)]:
            if key in self.object_nodes:
                obs[observation_index] = len(self.object_nodes[key]) / max_count
            if (key + "_opponent") in self.object_nodes:
                obs[observation_index + 1] = len(self.object_nodes[(key + "_opponent")]) / max_count
            observation_index += 2

        #   1x research points [cur player]
        #   1x researched coal [cur player]
        #   1x researched uranium [cur player]
        obs[observation_index] = game.state["teamStates"][team]["researchPoints"] / 200.0
        obs[observation_index+1] = float(game.state["teamStates"][team]["researched"]["coal"])
        obs[observation_index+2] = float(game.state["teamStates"][team]["researched"]["uranium"])

        return obs

    def action_code_to_action(self, action_code, game, unit=None, city_tile=None, team=None):
        """
        Takes an action in the environment according to actionCode:
            actionCode: Index of action to take into the action array.
        Returns: An action.
        """
        # Map actionCode index into to a constructed Action object
        try:
            x = None
            y = None
            if city_tile is not None:
                x = city_tile.pos.x
                y = city_tile.pos.y
            elif unit is not None:
                x = unit.pos.x
                y = unit.pos.y
            
            if city_tile != None:
                action =  self.actionSpaceMapCities[action_code%len(self.actionSpaceMapCities)](
                    game=game,
                    unit_id=unit.id if unit else None,
                    unit=unit,
                    city_id=city_tile.city_id if city_tile else None,
                    citytile=city_tile,
                    team=team,
                    x=x,
                    y=y
                )

                # If the city action is invalid, default to research action automatically
                if not action.is_valid(game, actions_validated=[]):
                    action = ResearchAction(
                        game=game,
                        unit_id=unit.id if unit else None,
                        unit=unit,
                        city_id=city_tile.city_id if city_tile else None,
                        citytile=city_tile,
                        team=team,
                        x=x,
                        y=y
                    )
            else:
                action =  self.actionSpaceMapUnits[action_code%len(self.actionSpaceMapUnits)](
                    game=game,
                    unit_id=unit.id if unit else None,
                    unit=unit,
                    city_id=city_tile.city_id if city_tile else None,
                    citytile=city_tile,
                    team=team,
                    x=x,
                    y=y
                )
            
            return action
        except Exception as e:
            # Not a valid action
            print(e)
            return None

    def take_action(self, action_code, game, unit=None, city_tile=None, team=None):
        """
        Takes an action in the environment according to actionCode:
            actionCode: Index of action to take into the action array.
        """
        action = self.action_code_to_action(action_code, game, unit, city_tile, team)
        self.match_controller.take_action(action)
    
    def game_start(self, game):
        """
        This funciton is called at the start of each game. Use this to
        reset and initialize per game. Note that self.team may have
        been changed since last game. The game map has been created
        and starting units placed.

        Args:
            game ([type]): Game.
        """
        self.last_generated_fuel = game.stats["teamStats"][self.team]["fuelGenerated"]
        self.last_resources_collected = copy.deepcopy(game.stats["teamStats"][self.team]["resourcesCollected"])
        if self.stats != None:
            self.stats_last_game =  self.stats
        self.stats = {
            "rew/r_total": 0,
            "rew/r_wood": 0,
            "rew/r_coal": 0,
            "rew/r_uranium": 0,
            "rew/r_research": 0,
            "rew/r_city_tiles_end": 0,
            "rew/r_fuel_collected":0,
            "rew/r_units":0,
            "rew/r_city_tiles":0,
            "game/turns": 0,
            "game/research": 0,
            "game/unit_count": 0,
            "game/cart_count": 0,
            "game/city_count": 0,
            "game/city_tiles": 0,
            "game/wood_rate_mined": 0,
            "game/coal_rate_mined": 0,
            "game/uranium_rate_mined": 0,
        }
        self.is_last_turn = False

        # Calculate starting map resources
        type_map = {
            Constants.RESOURCE_TYPES.WOOD: "WOOD",
            Constants.RESOURCE_TYPES.COAL: "COAL",
            Constants.RESOURCE_TYPES.URANIUM: "URANIUM",
        }

        self.fuel_collected_last = 0
        self.fuel_start = {}
        self.fuel_last = {}
        for type, type_upper in type_map.items():
            self.fuel_start[type] = 0
            self.fuel_last[type] = 0
            for c in game.map.resources_by_type[type]:
                self.fuel_start[type] += c.resource.amount * game.configs["parameters"]["RESOURCE_TO_FUEL_RATE"][type_upper]

        self.research_last = 0
        self.units_last = 0
        self.city_tiles_last = 0

    def get_reward(self, game, is_game_finished, is_new_turn, is_game_error):
        """
        Returns the reward function for this step of the game.
        """
        if is_game_error:
            # Game environment step failed, assign a game lost reward to not incentivise this
            print("Game failed due to error")
            return -1.0

        if not is_new_turn and not is_game_finished:
            # Only apply rewards at the start of each turn
            return 0

        # Get some basic stats
        unit_count = len(game.state["teamStates"][self.team % 2]["units"])
        cart_count = 0
        for id, u in game.state["teamStates"][self.team % 2]["units"].items():
            if u.type == Constants.UNIT_TYPES.CART:
                cart_count += 1

        unit_count_opponent = len(game.state["teamStates"][(self.team + 1) % 2]["units"])
        research = min(game.state["teamStates"][self.team]["researchPoints"], 200.0) # Cap research points at 200
        city_count = 0
        city_count_opponent = 0
        city_tile_count = 0
        city_tile_count_opponent = 0
        for city in game.cities.values():
            if city.team == self.team:
                city_count += 1
            else:
                city_count_opponent += 1

            for cell in city.city_cells:
                if city.team == self.team:
                    city_tile_count += 1
                else:
                    city_tile_count_opponent += 1
        
        # Basic stats
        self.stats["game/research"] = research
        self.stats["game/city_tiles"] = city_tile_count
        self.stats["game/city_count"] = city_count
        self.stats["game/unit_count"] = unit_count
        self.stats["game/cart_count"] = cart_count
        self.stats["game/turns"] = game.state["turn"]

        rewards = {}

        # Give up to 1.0 reward for each resource based on % of total mined.
        type_map = {
            Constants.RESOURCE_TYPES.WOOD: "WOOD",
            Constants.RESOURCE_TYPES.COAL: "COAL",
            Constants.RESOURCE_TYPES.URANIUM: "URANIUM",
        }
        fuel_now = {}
        for type, type_upper in type_map.items():
            fuel_now = game.stats["teamStats"][self.team]["resourcesCollected"][type] * game.configs["parameters"]["RESOURCE_TO_FUEL_RATE"][type_upper]
            rewards["rew/r_%s" % type] = (fuel_now - self.fuel_last[type]) / self.fuel_start[type]
            self.stats["game/%s_rate_mined" % type] = fuel_now / self.fuel_start[type]
            self.fuel_last[type] = fuel_now
        
        # Give more incentive for coal and uranium
        rewards["rew/r_%s" % Constants.RESOURCE_TYPES.COAL] *= 2
        rewards["rew/r_%s" % Constants.RESOURCE_TYPES.URANIUM] *= 4
        
        # Give a reward based on amount of fuel collected. 1.0 reward for each 20K fuel gathered.
        fuel_collected = game.stats["teamStats"][self.team]["fuelGenerated"]
        rewards["rew/r_fuel_collected"] = ( (fuel_collected - self.fuel_collected_last) / 20000 )
        self.fuel_collected_last = fuel_collected

        # Give a reward for unit creation/death. 0.05 reward per unit.
        rewards["rew/r_units"] = (unit_count - self.units_last) * 0.05
        self.units_last = unit_count

        # Give a reward for unit creation/death. 0.1 reward per city.
        rewards["rew/r_city_tiles"] = (city_tile_count - self.city_tiles_last) * 0.1
        self.city_tiles_last = city_tile_count

        # Tiny reward for research to help. Up to 0.5 reward for this.
        rewards["rew/r_research"] = (research - self.research_last) / (200 * 2)
        self.research_last = research
        
        # Give a reward up to around 50.0 based on number of city tiles at the end of the game
        rewards["rew/r_city_tiles_end"] = 0
        if is_game_finished:
            self.is_last_turn = True
            rewards["rew/r_city_tiles_end"] = city_tile_count
        
        
        # Update the stats and total reward
        reward = 0
        for name, value in rewards.items():
            self.stats[name] += value
            reward += value
        self.stats["rew/r_total"] += reward

        # Print the final game stats sometimes
        if is_game_finished and random.random() <= 0.15:
            stats_string = []
            for key, value in self.stats.items():
                stats_string.append("%s=%.2f" % (key, value))
            print(",".join(stats_string))


        return reward
        
    

    def process_turn(self, game, team):
        """
        Decides on a set of actions for the current turn. Not used in training, only inference.
        Returns: Array of actions to perform.
        """
        start_time = time.time()
        actions = []
        new_turn = True

        # Inference the model per-unit
        units = game.state["teamStates"][team]["units"].values()
        for unit in units:
            if unit.can_act():
                obs = self.get_observation(game, unit, None, unit.team, new_turn)
                action_code, _states = self.model.predict(obs, deterministic=False)
                if action_code is not None:
                    actions.append(
                        self.action_code_to_action(action_code, game=game, unit=unit, city_tile=None, team=unit.team))
                new_turn = False

        # Inference the model per-city
        cities = game.cities.values()
        for city in cities:
            if city.team == team:
                for cell in city.city_cells:
                    city_tile = cell.city_tile
                    if city_tile.can_act():
                        obs = self.get_observation(game, None, city_tile, city.team, new_turn)
                        action_code, _states = self.model.predict(obs, deterministic=False)
                        if action_code is not None:
                            actions.append(
                                self.action_code_to_action(action_code, game=game, unit=None, city_tile=city_tile,
                                                           team=city.team))
                        new_turn = False

        time_taken = time.time() - start_time
        if time_taken > 0.5:  # Warn if larger than 0.5 seconds.
            print("WARNING: Inference took %.3f seconds for computing actions. Limit is 1 second." % time_taken,
                  file=sys.stderr)

        return actions
# Out:
# Overwriting agent_policy.py

# %% [markdown]
# # Build the environment for training
#
# Notes on metrics:
# * An Episode is a single game between your RL agent and it's opponent. This is generally 360 turns, spanning more than 360 unit + city decision steps.
# * Mean episode length (ep_len_mean) is the number of decision made per game. The larger this gets, means that it is making more unit + city decision per game, meaning that more units and cities were alive for longer during the game.
# * Episode reward mean (ep_rew_mean), is set up as micro-reward funciton for faster learning. Per turn it gets a small reward based on the number of cities and units alive. It gets a really big reward based on the number of cities and units alive at the end of the game.

# %%
import argparse
import glob
import os
import random
from typing import Callable

from stable_baselines3 import PPO  # pip install stable-baselines3
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.vec_env import SubprocVecEnv

from importlib import reload
import agent_policy
# reload(agent_policy) # Reload the file from disk incase the above agent-writing cell block was edited
from agent_policy import AgentPolicy

from luxai2021.env.agent import Agent
from luxai2021.env.lux_env import LuxEnvironment
from luxai2021.game.constants import LuxMatchConfigs_Default


# Default Lux configs
configs = LuxMatchConfigs_Default

# Create a default opponent agent
opponent = Agent()

# Create a RL agent in training mode
player = AgentPolicy(mode="train")

# Create the Lux environment
env = LuxEnvironment(configs=configs,
                     learning_agent=player,
                     opponent_agent=opponent)

# Define the model, you can pick other RL algos from Stable Baselines3 instead if you like
model = PPO("MlpPolicy",
                env,
                verbose=1,
                tensorboard_log="./lux_tensorboard/",
                learning_rate=0.001,
                gamma=0.999,
                gae_lambda=0.95,
                batch_size=2048 * 8,
                n_steps=2048 * 8
            )

# Define a learning rate schedule
# (number of steps, learning_rate)
schedule = [
    #(2000000, 0.01),
    (6000000, 0.001),
    (6000000, 0.0001),
]
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Running in inference-only mode.

# %% [markdown]
# # Train the agent against a dummy opponent

# %%
from stable_baselines3.common.utils import get_schedule_fn

print("Training model...")
run_id = 1

# Save a checkpoint every 1M steps
checkpoint_callback = CheckpointCallback(save_freq=1000000,
                                         save_path='./models/',
                                         name_prefix=f'rl_model_{run_id}')

# Train the policy
for steps, learning_rate in schedule:
    model.lr_schedule = get_schedule_fn(learning_rate)
    model.learn(total_timesteps=steps,
                callback=checkpoint_callback,
                reset_num_timesteps = False)

# Save final model
model.save(path=f'models/model.zip')

print("Done training model.")
# Out:
# Training model...
# Logging to ./lux_tensorboard/PPO_0
# rew/r_total=0.16,rew/r_wood=0.11,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=196.00,game/research=12.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.11,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.08,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=151.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=116.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=116.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=35.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.28,rew/r_wood=0.22,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=311.00,game/research=19.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.22,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=156.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.11,rew/r_wood=0.08,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=151.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.08,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=32.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.11,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=155.00,game/research=12.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.07,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=152.00,game/research=10.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.11,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=14.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 146      |
# |    ep_rew_mean     | 0.34     |
# | time/              |          |
# |    fps             | 403      |
# |    iterations      | 1        |
# |    time_elapsed    | 40       |
# |    total_timesteps | 16384    |
# ---------------------------------
# rew/r_total=0.17,rew/r_wood=0.09,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=198.00,game/research=10.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.09,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.07,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=156.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.15,rew/r_wood=0.11,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=157.00,game/research=13.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.11,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.08,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=12.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=2.03,rew/r_wood=0.57,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.10,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.06,rew/r_units=0.20,rew/r_city_tiles=0.10,game/turns=198.00,game/research=40.00,game/unit_count=4.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.57,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=156.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.07,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=74.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.09,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=72.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=116.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.04,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=72.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=234.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=34.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.07,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=76.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.24,rew/r_wood=0.17,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=153.00,game/research=18.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.17,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.04,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.11,rew/r_wood=0.09,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=77.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.09,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 128         |
# |    ep_rew_mean          | 0.238       |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 2           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014535585 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.553      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0774      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00388    |
# |    value_loss           | 0.207       |
# -----------------------------------------
# rew/r_total=0.08,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=116.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=72.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.36,rew/r_wood=0.28,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=193.00,game/research=19.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.28,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.16,rew/r_wood=0.09,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=17.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.09,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.73,rew/r_wood=0.54,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.11,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=360.00,game/research=45.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.54,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.07,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.14,rew/r_wood=0.09,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=116.00,game/research=11.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.09,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.57,rew/r_wood=0.40,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.10,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=360.00,game/research=40.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.40,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.36,rew/r_wood=0.24,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.08,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.04,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=237.00,game/research=31.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.24,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.17,rew/r_wood=0.10,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.06,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=-0.00,rew/r_city_tiles=0.00,game/turns=196.00,game/research=23.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.10,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=1.30,rew/r_wood=0.11,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.01,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=198.00,game/research=9.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.11,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.12,rew/r_wood=0.08,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=112.00,game/research=12.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.08,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.31,rew/r_wood=0.16,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.07,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=198.00,game/research=26.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.16,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.24,rew/r_wood=0.19,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=231.00,game/research=18.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.19,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=35.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=112.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 135          |
# |    ep_rew_mean          | 0.214        |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 3            |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0047084386 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.00324      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0288       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 0.0707       |
# ------------------------------------------
# rew/r_total=0.09,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=156.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.46,rew/r_wood=0.13,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.11,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.20,rew/r_city_tiles=0.00,game/turns=198.00,game/research=42.00,game/unit_count=4.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.13,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.10,rew/r_wood=0.08,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=116.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.08,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.25,rew/r_wood=0.13,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.09,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=271.00,game/research=37.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.13,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=32.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.27,rew/r_wood=0.18,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.07,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=277.00,game/research=26.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.18,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.08,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=73.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=7.51,rew/r_wood=0.36,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.14,rew/r_city_tiles_end=6.00,rew/r_fuel_collected=0.11,rew/r_units=0.30,rew/r_city_tiles=0.60,game/turns=198.00,game/research=57.00,game/unit_count=6.00,game/cart_count=1.00,game/city_count=1.00,game/city_tiles=6.00,game/wood_rate_mined=0.36,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | 0.622        |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 4            |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0069808625 |
# |    clip_fraction        | 0.00602      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.218        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0071       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 0.0237       |
# ------------------------------------------
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.08,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=9.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.13,rew/r_wood=0.08,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=-0.00,rew/r_city_tiles=0.00,game/turns=196.00,game/research=15.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.08,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.19,rew/r_wood=0.12,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=151.00,game/research=18.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.12,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.11,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=198.00,game/research=9.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=2.50,rew/r_wood=0.14,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.08,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.03,rew/r_units=0.05,rew/r_city_tiles=0.20,game/turns=360.00,game/research=31.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=2.00,game/wood_rate_mined=0.14,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=35.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.10,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=77.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.08,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=-0.00,rew/r_city_tiles=0.00,game/turns=120.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.08,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.12,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=156.00,game/research=17.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=116.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=152.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.27,rew/r_wood=0.16,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=198.00,game/research=15.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.16,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=7.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=76.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=33.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | 0.286        |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 5            |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0044255294 |
# |    clip_fraction        | 0.00241      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0774       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 0.165        |
# ------------------------------------------
# rew/r_total=2.55,rew/r_wood=0.18,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.08,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.04,rew/r_units=0.05,rew/r_city_tiles=0.20,game/turns=360.00,game/research=33.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=2.00,game/wood_rate_mined=0.18,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=36.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.11,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=351.00,game/research=15.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=4.34,rew/r_wood=0.37,rew/r_coal=0.13,rew/r_uranium=0.00,rew/r_research=0.21,rew/r_city_tiles_end=3.00,rew/r_fuel_collected=0.09,rew/r_units=0.25,rew/r_city_tiles=0.30,game/turns=358.00,game/research=84.00,game/unit_count=5.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=3.00,game/wood_rate_mined=0.37,game/coal_rate_mined=0.07,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=116.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=1.25,rew/r_wood=0.06,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.01,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=198.00,game/research=14.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.06,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.17,rew/r_wood=0.12,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=192.00,game/research=14.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.12,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.23,rew/r_wood=0.19,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.03,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=160.00,game/research=13.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.19,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=75.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.23,rew/r_wood=0.15,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.06,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=192.00,game/research=24.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.15,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.12,rew/r_wood=0.07,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=195.00,game/research=16.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.07,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.02,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=32.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.02,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=76.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=111.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.22,rew/r_wood=0.17,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=197.00,game/research=20.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.17,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.01,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=31.00,game/research=4.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.03,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=71.00,game/research=6.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.05,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=116.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.06,rew/r_wood=0.03,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=156.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.03,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.08,rew/r_wood=0.04,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.02,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=116.00,game/research=8.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.04,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.14,rew/r_wood=0.09,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.01,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=191.00,game/research=16.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.09,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 104          |
# |    ep_rew_mean          | 0.184        |
# ...
# rew/r_total=1.41,rew/r_wood=0.18,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.04,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.04,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=159.00,game/research=16.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.18,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.28e+03     |
# |    ep_rew_mean          | 10.9         |
# | time/                   |              |
# |    fps                  | 1234         |
# |    iterations           | 357          |
# |    time_elapsed         | 9605         |
# |    total_timesteps      | 11862016     |
# | train/                  |              |
# |    approx_kl            | 0.0009937419 |
# |    clip_fraction        | 0.00292      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.305       |
# |    explained_variance   | 0.881        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.103        |
# |    n_updates            | 7230         |
# |    policy_gradient_loss | -0.000212    |
# |    value_loss           | 0.208        |
# ------------------------------------------
# rew/r_total=10.88,rew/r_wood=1.04,rew/r_coal=0.11,rew/r_uranium=0.00,rew/r_research=0.30,rew/r_city_tiles_end=8.00,rew/r_fuel_collected=0.22,rew/r_units=0.40,rew/r_city_tiles=0.80,game/turns=198.00,game/research=121.00,game/unit_count=8.00,game/cart_count=0.00,game/city_count=5.00,game/city_tiles=8.00,game/wood_rate_mined=1.04,game/coal_rate_mined=0.06,game/uranium_rate_mined=0.00
# rew/r_total=14.84,rew/r_wood=0.78,rew/r_coal=0.03,rew/r_uranium=0.00,rew/r_research=0.37,rew/r_city_tiles_end=12.00,rew/r_fuel_collected=0.22,rew/r_units=0.25,rew/r_city_tiles=1.20,game/turns=198.00,game/research=148.00,game/unit_count=5.00,game/cart_count=0.00,game/city_count=4.00,game/city_tiles=12.00,game/wood_rate_mined=0.78,game/coal_rate_mined=0.01,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.2e+03      |
# |    ep_rew_mean          | 10           |
# | time/                   |              |
# |    fps                  | 1233         |
# |    iterations           | 358          |
# |    time_elapsed         | 9631         |
# |    total_timesteps      | 11878400     |
# | train/                  |              |
# |    approx_kl            | 0.0013242157 |
# |    clip_fraction        | 0.00357      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.291       |
# |    explained_variance   | 0.913        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0619       |
# |    n_updates            | 7240         |
# |    policy_gradient_loss | -0.000884    |
# |    value_loss           | 0.131        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.21e+03     |
# |    ep_rew_mean          | 9.94         |
# | time/                   |              |
# |    fps                  | 1231         |
# |    iterations           | 359          |
# |    time_elapsed         | 9658         |
# |    total_timesteps      | 11894784     |
# | train/                  |              |
# |    approx_kl            | 0.0016626673 |
# |    clip_fraction        | 0.00818      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.3         |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.094        |
# |    n_updates            | 7250         |
# |    policy_gradient_loss | -0.000387    |
# |    value_loss           | 0.19         |
# ------------------------------------------
# rew/r_total=26.39,rew/r_wood=1.45,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=21.00,rew/r_fuel_collected=0.40,rew/r_units=0.95,rew/r_city_tiles=2.10,game/turns=311.00,game/research=200.00,game/unit_count=19.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=21.00,game/wood_rate_mined=1.45,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=13.77,rew/r_wood=1.52,rew/r_coal=0.25,rew/r_uranium=0.00,rew/r_research=0.49,rew/r_city_tiles_end=10.00,rew/r_fuel_collected=0.31,rew/r_units=0.20,rew/r_city_tiles=1.00,game/turns=198.00,game/research=197.00,game/unit_count=4.00,game/cart_count=0.00,game/city_count=5.00,game/city_tiles=10.00,game/wood_rate_mined=1.52,game/coal_rate_mined=0.12,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.22e+03     |
# |    ep_rew_mean          | 10           |
# | time/                   |              |
# |    fps                  | 1229         |
# |    iterations           | 360          |
# |    time_elapsed         | 9684         |
# |    total_timesteps      | 11911168     |
# | train/                  |              |
# |    approx_kl            | 0.0018570768 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.271       |
# |    explained_variance   | 0.844        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.109        |
# |    n_updates            | 7260         |
# |    policy_gradient_loss | -0.000702    |
# |    value_loss           | 0.223        |
# ------------------------------------------
# rew/r_total=15.86,rew/r_wood=0.44,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.19,rew/r_city_tiles_end=13.00,rew/r_fuel_collected=0.27,rew/r_units=0.65,rew/r_city_tiles=1.30,game/turns=198.00,game/research=77.00,game/unit_count=13.00,game/cart_count=0.00,game/city_count=8.00,game/city_tiles=13.00,game/wood_rate_mined=0.44,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.25e+03     |
# |    ep_rew_mean          | 9.83         |
# | time/                   |              |
# |    fps                  | 1228         |
# |    iterations           | 361          |
# |    time_elapsed         | 9711         |
# |    total_timesteps      | 11927552     |
# | train/                  |              |
# |    approx_kl            | 0.0008676081 |
# |    clip_fraction        | 0.00374      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.286       |
# |    explained_variance   | 0.683        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.135        |
# |    n_updates            | 7270         |
# |    policy_gradient_loss | -0.000124    |
# |    value_loss           | 0.276        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.25e+03     |
# |    ep_rew_mean          | 9.8          |
# | time/                   |              |
# |    fps                  | 1226         |
# |    iterations           | 362          |
# |    time_elapsed         | 9738         |
# |    total_timesteps      | 11943936     |
# | train/                  |              |
# |    approx_kl            | 0.0030334604 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.345       |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.196        |
# |    n_updates            | 7280         |
# |    policy_gradient_loss | -0.000683    |
# |    value_loss           | 0.396        |
# ------------------------------------------
# rew/r_total=9.22,rew/r_wood=0.50,rew/r_coal=0.01,rew/r_uranium=0.00,rew/r_research=0.26,rew/r_city_tiles_end=7.00,rew/r_fuel_collected=0.15,rew/r_units=0.60,rew/r_city_tiles=0.70,game/turns=198.00,game/research=104.00,game/unit_count=12.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=7.00,game/wood_rate_mined=0.50,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=14.10,rew/r_wood=0.49,rew/r_coal=0.02,rew/r_uranium=0.00,rew/r_research=0.17,rew/r_city_tiles_end=12.00,rew/r_fuel_collected=0.12,rew/r_units=0.10,rew/r_city_tiles=1.20,game/turns=198.00,game/research=69.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=12.00,game/wood_rate_mined=0.49,game/coal_rate_mined=0.01,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.27e+03     |
# |    ep_rew_mean          | 10.4         |
# | time/                   |              |
# |    fps                  | 1224         |
# |    iterations           | 363          |
# |    time_elapsed         | 9765         |
# |    total_timesteps      | 11960320     |
# | train/                  |              |
# |    approx_kl            | 0.0007912559 |
# |    clip_fraction        | 0.00239      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.339       |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.202        |
# |    n_updates            | 7290         |
# |    policy_gradient_loss | -0.000717    |
# |    value_loss           | 0.411        |
# ------------------------------------------
# rew/r_total=7.40,rew/r_wood=1.10,rew/r_coal=0.03,rew/r_uranium=0.00,rew/r_research=0.26,rew/r_city_tiles_end=5.00,rew/r_fuel_collected=0.21,rew/r_units=0.30,rew/r_city_tiles=0.50,game/turns=198.00,game/research=105.00,game/unit_count=6.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=5.00,game/wood_rate_mined=1.10,game/coal_rate_mined=0.02,game/uranium_rate_mined=0.00
# rew/r_total=0.21,rew/r_wood=0.09,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.05,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.03,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=198.00,game/research=19.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.09,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=7.11,rew/r_wood=0.38,rew/r_coal=0.37,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=5.00,rew/r_fuel_collected=0.27,rew/r_units=0.10,rew/r_city_tiles=0.50,game/turns=279.00,game/research=200.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=5.00,game/wood_rate_mined=0.38,game/coal_rate_mined=0.18,game/uranium_rate_mined=0.00
# rew/r_total=7.78,rew/r_wood=1.10,rew/r_coal=0.23,rew/r_uranium=0.00,rew/r_research=0.49,rew/r_city_tiles_end=5.00,rew/r_fuel_collected=0.25,rew/r_units=0.20,rew/r_city_tiles=0.50,game/turns=360.00,game/research=196.00,game/unit_count=4.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=5.00,game/wood_rate_mined=1.10,game/coal_rate_mined=0.12,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.29e+03      |
# |    ep_rew_mean          | 10.5          |
# | time/                   |               |
# |    fps                  | 1223          |
# |    iterations           | 364           |
# |    time_elapsed         | 9792          |
# |    total_timesteps      | 11976704      |
# | train/                  |               |
# |    approx_kl            | 0.00051631406 |
# |    clip_fraction        | 0.000793      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.319        |
# |    explained_variance   | 0.807         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.4           |
# |    n_updates            | 7300          |
# |    policy_gradient_loss | -0.000236     |
# |    value_loss           | 0.807         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.33e+03     |
# |    ep_rew_mean          | 10.8         |
# | time/                   |              |
# |    fps                  | 1221         |
# |    iterations           | 365          |
# |    time_elapsed         | 9819         |
# |    total_timesteps      | 11993088     |
# | train/                  |              |
# |    approx_kl            | 0.0028255219 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.314       |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.112        |
# |    n_updates            | 7310         |
# |    policy_gradient_loss | -0.000747    |
# |    value_loss           | 0.228        |
# ------------------------------------------
# rew/r_total=5.80,rew/r_wood=0.48,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.23,rew/r_city_tiles_end=4.00,rew/r_fuel_collected=0.14,rew/r_units=0.55,rew/r_city_tiles=0.40,game/turns=198.00,game/research=91.00,game/unit_count=11.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=4.00,game/wood_rate_mined=0.48,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.26e+03     |
# |    ep_rew_mean          | 10.3         |
# | time/                   |              |
# |    fps                  | 1219         |
# |    iterations           | 366          |
# |    time_elapsed         | 9846         |
# |    total_timesteps      | 12009472     |
# | train/                  |              |
# |    approx_kl            | 0.0009015793 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.253       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.139        |
# |    n_updates            | 7320         |
# |    policy_gradient_loss | -0.000251    |
# |    value_loss           | 0.283        |
# ------------------------------------------
# rew/r_total=13.23,rew/r_wood=1.56,rew/r_coal=0.19,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=9.00,rew/r_fuel_collected=0.63,rew/r_units=0.45,rew/r_city_tiles=0.90,game/turns=357.00,game/research=200.00,game/unit_count=9.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=9.00,game/wood_rate_mined=1.56,game/coal_rate_mined=0.10,game/uranium_rate_mined=0.00
# rew/r_total=13.86,rew/r_wood=0.94,rew/r_coal=0.86,rew/r_uranium=0.00,rew/r_research=0.22,rew/r_city_tiles_end=10.00,rew/r_fuel_collected=0.39,rew/r_units=0.45,rew/r_city_tiles=1.00,game/turns=198.00,game/research=89.00,game/unit_count=9.00,game/cart_count=0.00,game/city_count=4.00,game/city_tiles=10.00,game/wood_rate_mined=0.94,game/coal_rate_mined=0.43,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 1218         |
# |    iterations           | 367          |
# |    time_elapsed         | 9872         |
# |    total_timesteps      | 12025856     |
# | train/                  |              |
# |    approx_kl            | 0.0015295787 |
# |    clip_fraction        | 0.00338      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.306       |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0362       |
# |    n_updates            | 7330         |
# |    policy_gradient_loss | -0.00064     |
# |    value_loss           | 0.0783       |
# ------------------------------------------
# Done training model.

# %%
# Save final model
model.save(path=f'models/model.zip')

print("Done training model.")
# Out:
# Done training model.

# %% [markdown]
# # Set up a Kaggle Submission and lux replay environment for the agent

# %%
"""
This downloads two required python package dependencies that are not pre-installed
by Kaggle yet.

This places the following two packages in the current working directory:
    luxai2021
    stable_baselines3
"""

import os
import shutil
import subprocess
import tempfile

def localize_package(git, branch, folder):
    if os.path.exists(folder):
        print("Already localized %s" % folder)
    else:
        # https://stackoverflow.com/questions/51239168/how-to-download-single-file-from-a-git-repository-using-python
        # Create temporary dir
        t = tempfile.mkdtemp()

        args = ['git', 'clone', '--depth=1', git, t, '-b', branch]
        res = subprocess.Popen(args, stdout=subprocess.PIPE)
        output, _error = res.communicate()

        if not _error:
            print(output)
        else:
            print(_error)
        
        # Copy desired file from temporary dir
        shutil.move(os.path.join(t, folder), '.')
        # Remove temporary dir
        shutil.rmtree(t, ignore_errors=True)

localize_package('https://github.com/glmcdona/LuxPythonEnvGym.git', 'main', 'luxai2021')
localize_package('https://github.com/glmcdona/LuxPythonEnvGym.git', 'main', 'kaggle_submissions')
localize_package('https://github.com/DLR-RM/stable-baselines3.git', 'master', 'stable_baselines3')
# Out:
# b''
# b''
# b''

# %%
# Move the dependent packages into kaggle submissions
# !mv luxai2021 kaggle_submissions
# !mv stable_baselines3 kaggle_submissions
# !rm ./kaggle_submissions/agent_policy.py
# !cp agent_policy.py kaggle_submissions

# Copy the agent and model to the submission 
# !cp ./agent_policy.py kaggle_submissions
# !cp ./models/model.zip kaggle_submissions

# !ls kaggle_submissions
# Out:
# rm: cannot remove './kaggle_submissions/agent_policy.py': No such file or directory
# agent_policy.py		  luxai2021  main_lux-ai-2021.py  stable_baselines3
# download_dependencies.py  main.py    model.zip

# %%
from kaggle_environments import make
import json
# run another match but with our empty agent
env = make("lux_ai_2021", configuration={"seed": 5621242, "loglevel": 2, "annotations": True}, debug=True)

# Play the environment where the RL agent plays against itself
steps = env.run(["./kaggle_submissions/main.py", "./kaggle_submissions/main.py"])
# Out:
# Loading environment football failed: No module named 'gfootball'
# Running in inference-only mode.
# Running in inference-only mode.
# [WARN] (match_VXnXUZ6Lfubb) - turn 27; Unit u_3 collided when trying to move e to (14, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 29; Unit u_2 collided when trying to move e to (14, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 48; Unit u_5 collided when trying to move e to (14, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 56; Unit u_4 collided when trying to move w to (0, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 57; Unit u_4 collided when trying to move w to (0, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 57; Unit u_3 collided when trying to move e to (14, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 58; Unit u_4 collided when trying to move w to (0, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 59; Unit u_5 collided when trying to move e to (14, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 60; Unit u_1 collided when trying to move w to (0, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 60; Unit u_6 collided when trying to move e to (10, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 61; Unit u_1 collided when trying to move w to (0, 3)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (12, 4) but unit cap reached. Build more CityTiles!; turn 67; cmd: bw 12 4
# [WARN] (match_VXnXUZ6Lfubb) - turn 70; Unit u_3 collided when trying to move w to (12, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 71; Unit u_4 collided when trying to move s to (0, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 74; Unit u_8 collided when trying to move w to (12, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 75; Unit u_3 collided when trying to move n to (12, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 75; Unit u_8 collided when trying to move w to (12, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 76; Unit u_3 collided when trying to move n to (12, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 76; Unit u_8 collided when trying to move w to (12, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 77; Unit u_4 collided when trying to move s to (0, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 77; Unit u_3 collided when trying to move n to (12, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 77; Unit u_8 collided when trying to move w to (12, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 78; Unit u_4 collided when trying to move s to (0, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 78; Unit u_3 collided when trying to move n to (12, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 78; Unit u_8 collided when trying to move w to (12, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 79; Unit u_3 collided when trying to move n to (12, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 79; Unit u_8 collided when trying to move w to (12, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 81; Unit u_8 collided when trying to move w to (12, 3)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (0, 3) but unit cap reached. Build more CityTiles!; turn 82; cmd: bw 0 3
# [WARN] (match_VXnXUZ6Lfubb) - turn 83; Unit u_9 collided when trying to move w to (12, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 83; Unit u_10 collided when trying to move e to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 84; Unit u_4 collided when trying to move s to (0, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 84; Unit u_10 collided when trying to move e to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 85; Unit u_4 collided when trying to move s to (0, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 86; Unit u_8 collided when trying to move e to (12, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 87; Unit u_11 collided when trying to move s to (0, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 87; Unit u_10 collided when trying to move e to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (9, 3) but unit cap reached. Build more CityTiles!; turn 88; cmd: bw 9 3
# [WARN] (match_VXnXUZ6Lfubb) - turn 88; Unit u_3 collided when trying to move e to (10, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 88; Unit u_10 collided when trying to move e to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 89; Unit u_4 collided when trying to move s to (0, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 89; Unit u_10 collided when trying to move e to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 89; Unit u_13 collided when trying to move n to (12, 3)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (14, 3) but unit cap reached. Build more CityTiles!; turn 90; cmd: bw 14 3
# [WARN] (match_VXnXUZ6Lfubb) - turn 90; Unit u_4 collided when trying to move s to (0, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 92; Unit u_15 collided when trying to move w to (1, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 92; Unit u_8 collided when trying to move e to (11, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 92; Unit u_3 collided when trying to move e to (10, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 93; Unit u_12 collided when trying to move w to (11, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 93; Unit u_13 collided when trying to move w to (10, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 94; Unit u_4 collided when trying to move s to (0, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 94; Unit u_10 collided when trying to move e to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 94; Unit u_14 collided when trying to move w to (11, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 95; Unit u_4 collided when trying to move s to (0, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 95; Unit u_9 collided when trying to move w to (11, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 95; Unit u_10 collided when trying to move e to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 95; Unit u_14 collided when trying to move w to (11, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 96; Unit u_4 collided when trying to move s to (0, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 96; Unit u_9 collided when trying to move w to (11, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 96; Unit u_10 collided when trying to move e to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 96; Unit u_13 collided when trying to move w to (10, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 96; Unit u_14 collided when trying to move w to (11, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 97; Unit u_10 collided when trying to move e to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 98; Unit u_15 collided when trying to move w to (1, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 98; Unit u_10 collided when trying to move e to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 98; Unit u_13 collided when trying to move w to (11, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 99; Unit u_9 collided when trying to move n to (11, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 99; Unit u_14 collided when trying to move w to (11, 2)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (11, 1) but unit cap reached. Build more CityTiles!; turn 100; cmd: bw 11 1
# [WARN] (match_VXnXUZ6Lfubb) - turn 100; Unit u_1 collided when trying to move w to (1, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 101; Unit u_7 collided when trying to move w to (11, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 102; Unit u_15 collided when trying to move w to (1, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 103; Unit u_1 collided when trying to move w to (0, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 103; Unit u_11 collided when trying to move s to (1, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 103; Unit u_3 collided when trying to move e to (10, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 103; Unit u_9 collided when trying to move e to (10, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 105; Unit u_14 collided when trying to move w to (11, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 107; Unit u_9 collided when trying to move e to (10, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 108; Unit u_8 collided when trying to move w to (10, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 109; Unit u_18 collided when trying to move e to (2, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 109; Unit u_7 collided when trying to move w to (11, 2)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (12, 3) but unit cap reached. Build more CityTiles!; turn 110; cmd: bw 12 3
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (11, 3) but unit cap reached. Build more CityTiles!; turn 110; cmd: bw 11 3
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (14, 3) but unit cap reached. Build more CityTiles!; turn 111; cmd: bw 14 3
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (11, 3) but unit cap reached. Build more CityTiles!; turn 111; cmd: bw 11 3
# [WARN] (match_VXnXUZ6Lfubb) - turn 111; Unit u_5 collided when trying to move n to (15, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 111; Unit u_8 collided when trying to move w to (10, 2)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (14, 3) but unit cap reached. Build more CityTiles!; turn 112; cmd: bw 14 3
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (14, 4) but unit cap reached. Build more CityTiles!; turn 112; cmd: bw 14 4
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (11, 3) but unit cap reached. Build more CityTiles!; turn 112; cmd: bw 11 3
# [WARN] (match_VXnXUZ6Lfubb) - turn 112; Unit u_18 collided when trying to move e to (2, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 112; Unit u_5 collided when trying to move n to (15, 2)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (13, 3) but unit cap reached. Build more CityTiles!; turn 113; cmd: bw 13 3
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (14, 4) but unit cap reached. Build more CityTiles!; turn 113; cmd: bw 14 4
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (11, 3) but unit cap reached. Build more CityTiles!; turn 113; cmd: bw 11 3
# [WARN] (match_VXnXUZ6Lfubb) - turn 113; Unit u_18 collided when trying to move e to (2, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 113; Unit u_5 collided when trying to move n to (15, 2)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (14, 4) but unit cap reached. Build more CityTiles!; turn 114; cmd: bw 14 4
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (11, 3) but unit cap reached. Build more CityTiles!; turn 114; cmd: bw 11 3
# [WARN] (match_VXnXUZ6Lfubb) - turn 114; Unit u_5 collided when trying to move n to (15, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 115; Unit u_5 collided when trying to move n to (15, 2)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (3, 2) but unit cap reached. Build more CityTiles!; turn 122; cmd: bw 3 2
# [WARN] (match_VXnXUZ6Lfubb) - turn 122; Unit u_31 collided when trying to move w to (8, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 123; Unit u_11 collided when trying to move s to (3, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 123; Unit u_38 collided when trying to move e to (1, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 124; Unit u_38 collided when trying to move e to (1, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 124; Unit u_27 collided when trying to move e to (15, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 125; Unit u_32 collided when trying to move e to (3, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 125; Unit u_27 collided when trying to move e to (15, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 126; Unit u_27 collided when trying to move e to (15, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 126; Unit u_36 collided when trying to move e to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 127; Unit u_11 collided when trying to move e to (3, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 127; Unit u_36 collided when trying to move e to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 127; Unit u_40 collided when trying to move s to (15, 3)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (12, 4) but unit cap reached. Build more CityTiles!; turn 128; cmd: bw 12 4
# [WARN] (match_VXnXUZ6Lfubb) - turn 129; Unit u_23 collided when trying to move s to (3, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 129; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 129; Unit u_41 collided when trying to move s to (14, 5)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (6, 2) but unit cap reached. Build more CityTiles!; turn 130; cmd: bw 6 2
# [WARN] (match_VXnXUZ6Lfubb) - turn 130; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (12, 3) but unit cap reached. Build more CityTiles!; turn 131; cmd: bw 12 3
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (6, 2) but unit cap reached. Build more CityTiles!; turn 131; cmd: bw 6 2
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (6, 3) but unit cap reached. Build more CityTiles!; turn 131; cmd: bw 6 3
# [WARN] (match_VXnXUZ6Lfubb) - turn 131; Unit u_11 collided when trying to move e to (3, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 131; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 132; Unit u_11 collided when trying to move e to (3, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 132; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (3, 3) but unit cap reached. Build more CityTiles!; turn 133; cmd: bw 3 3
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (0, 3) but unit cap reached. Build more CityTiles!; turn 133; cmd: bw 0 3
# [WARN] (match_VXnXUZ6Lfubb) - turn 133; Unit u_1 collided when trying to move e to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 133; Unit u_3 collided when trying to move w to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 133; Unit u_38 collided when trying to move e to (4, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 133; Unit u_30 collided when trying to move w to (4, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 133; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 134; Unit u_1 collided when trying to move e to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 134; Unit u_3 collided when trying to move w to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 134; Unit u_31 collided when trying to move w to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 134; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 135; Unit u_46 collided when trying to move e to (4, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 135; Unit u_3 collided when trying to move n to (5, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 135; Unit u_31 collided when trying to move w to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 135; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 135; Unit u_35 collided when trying to move s to (13, 2)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to move unit u_23 onto opponent CityTile; turn 136; cmd: m u_23 e
# [WARN] (match_VXnXUZ6Lfubb) - turn 136; Unit u_11 collided when trying to move e to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 136; Unit u_38 collided when trying to move e to (5, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 136; Unit u_3 collided when trying to move n to (5, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 136; Unit u_31 collided when trying to move w to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 136; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 136; Unit u_35 collided when trying to move s to (13, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 136; Unit u_45 collided when trying to move w to (10, 2)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to move unit u_23 onto opponent CityTile; turn 137; cmd: m u_23 e
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (5, 1) but unit cap reached. Build more CityTiles!; turn 137; cmd: bw 5 1
# [WARN] (match_VXnXUZ6Lfubb) - turn 137; Unit u_1 collided when trying to move e to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 137; Unit u_11 collided when trying to move e to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 137; Unit u_3 collided when trying to move w to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 137; Unit u_1 collided when trying to move e to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 137; Unit u_31 collided when trying to move w to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 137; Unit u_31 collided when trying to move w to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 137; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 137; Unit u_33 collided when trying to move w to (5, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 137; Unit u_45 collided when trying to move w to (10, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 138; Unit u_1 collided when trying to move e to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 138; Unit u_11 collided when trying to move e to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 138; Unit u_3 collided when trying to move w to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 138; Unit u_1 collided when trying to move e to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 138; Unit u_31 collided when trying to move w to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 138; Unit u_31 collided when trying to move w to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 138; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 138; Unit u_45 collided when trying to move w to (10, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 139; Unit u_38 collided when trying to move e to (4, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 139; Unit u_3 collided when trying to move n to (5, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 139; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 139; Unit u_45 collided when trying to move w to (10, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 140; Unit u_32 collided when trying to move e to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 140; Unit u_3 collided when trying to move w to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 140; Unit u_31 collided when trying to move w to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 140; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 141; Unit u_11 collided when trying to move e to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 141; Unit u_1 collided when trying to move e to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 141; Unit u_31 collided when trying to move w to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 141; Unit u_23 collided when trying to move e to (4, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 141; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 141; Unit u_45 collided when trying to move w to (10, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 142; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 142; Unit u_30 collided when trying to move w to (5, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 142; Unit u_39 collided when trying to move w to (13, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 142; Unit u_45 collided when trying to move w to (10, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 143; Unit u_32 collided when trying to move e to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 143; Unit u_38 collided when trying to move e to (4, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 143; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 143; Unit u_31 collided when trying to move w to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 143; Unit u_39 collided when trying to move w to (13, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 143; Unit u_45 collided when trying to move w to (10, 2)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to move unit u_11 onto opponent CityTile; turn 144; cmd: m u_11 e
# [WARN] (match_VXnXUZ6Lfubb) - turn 144; Unit u_1 collided when trying to move e to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 144; Unit u_32 collided when trying to move e to (4, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 144; Unit u_31 collided when trying to move w to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 144; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 144; Unit u_33 collided when trying to move w to (5, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 144; Unit u_39 collided when trying to move w to (13, 2)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to move unit u_11 onto opponent CityTile; turn 145; cmd: m u_11 e
# [WARN] (match_VXnXUZ6Lfubb) - turn 145; Unit u_23 collided when trying to move e to (4, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 145; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 145; Unit u_31 collided when trying to move w to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to move unit u_11 onto opponent CityTile; turn 146; cmd: m u_11 e
# [WARN] (match_VXnXUZ6Lfubb) - turn 146; Unit u_1 collided when trying to move e to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - turn 146; Unit u_32 collided when trying to move e to (4, 2)
# [WARN] (match_VXnXUZ6Lfubb) - turn 146; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (14, 11) but unit cap reached. Build more CityTiles!; turn 147; cmd: bw 14 11
# [WARN] (match_VXnXUZ6Lfubb) - turn 147; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 147; Unit u_30 collided when trying to move s to (5, 3)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_3 onto opponent CityTile; turn 148; cmd: m u_3 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 148; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 148; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 148; Unit u_48 collided when trying to move s to (4, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 148; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 148; Unit u_33 collided when trying to move s to (6, 4)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_3 onto opponent CityTile; turn 149; cmd: m u_3 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 149; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 149; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 149; Unit u_32 collided when trying to move s to (3, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 149; Unit u_51 collided when trying to move s to (5, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 149; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 149; Unit u_33 collided when trying to move s to (6, 4)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 150; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 150; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 150; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 150; Unit u_33 collided when trying to move s to (6, 4)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 151; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 151; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 151; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 152; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 152; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 152; Unit u_10 collided when trying to move s to (15, 4)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 153; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 153; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 154; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 154; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 155; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 155; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 156; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 156; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 157; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 157; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 158; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 158; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 158; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 159; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 159; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 159; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 160; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 160; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 160; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 160; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 161; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 161; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 161; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 161; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 161; Unit u_76 collided when trying to move n to (9, 1)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 162; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 162; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 162; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 162; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 163; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 163; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 163; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 163; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 163; Unit u_89 collided when trying to move s to (13, 11)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 164; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 164; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 164; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 164; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 165; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 165; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 165; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 165; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_87 onto opponent CityTile; turn 165; cmd: m u_87 w
# [WARN] (match_VXnXUZ6Lfubb) - turn 165; Unit u_36 collided when trying to move s to (13, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 165; Unit u_85 collided when trying to move s to (12, 5)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 166; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 166; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 166; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 166; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 166; Unit u_91 collided when trying to move s to (3, 4)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 167; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 167; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 167; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 167; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (5, 2) but unit cap reached. Build more CityTiles!; turn 167; cmd: bw 5 2
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (15, 5) but unit cap reached. Build more CityTiles!; turn 167; cmd: bw 15 5
# [WARN] (match_VXnXUZ6Lfubb) - turn 167; Unit u_78 collided when trying to move s to (2, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 167; Unit u_89 collided when trying to move s to (13, 11)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 168; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 168; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 168; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 168; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 168; Unit u_78 collided when trying to move s to (2, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 168; Unit u_91 collided when trying to move s to (3, 4)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 169; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 169; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 169; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 169; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 169; Unit u_78 collided when trying to move s to (2, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 169; Unit u_91 collided when trying to move s to (3, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 169; Unit u_36 collided when trying to move s to (13, 11)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 170; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 170; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 170; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 170; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 170; Unit u_78 collided when trying to move s to (2, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 170; Unit u_91 collided when trying to move s to (3, 4)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 171; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 171; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 171; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 171; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (14, 12) but unit cap reached. Build more CityTiles!; turn 171; cmd: bw 14 12
# [WARN] (match_VXnXUZ6Lfubb) - turn 171; Unit u_91 collided when trying to move s to (3, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 171; Unit u_89 collided when trying to move s to (13, 11)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 172; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 172; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 172; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 172; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 172; Unit u_91 collided when trying to move s to (3, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 172; Unit u_92 collided when trying to move s to (2, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 172; Unit u_97 collided when trying to move n to (11, 0)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (3, 10) but unit cap reached. Build more CityTiles!; turn 173; cmd: bw 3 10
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 173; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 173; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 173; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 173; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 173; Unit u_36 collided when trying to move s to (13, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 173; Unit u_97 collided when trying to move n to (11, 0)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 174; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 174; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 174; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 174; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 175; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 175; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 175; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 175; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 175; Unit u_41 collided when trying to move n to (13, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 175; Unit u_86 collided when trying to move s to (12, 10)
# [WARN] (match_VXnXUZ6Lfubb) - turn 175; Unit u_85 collided when trying to move s to (12, 9)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 176; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 176; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 176; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 176; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 176; Unit u_41 collided when trying to move n to (13, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 176; Unit u_86 collided when trying to move s to (12, 10)
# [WARN] (match_VXnXUZ6Lfubb) - turn 176; Unit u_85 collided when trying to move s to (12, 9)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 177; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 177; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 177; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 177; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (12, 10) but unit cap reached. Build more CityTiles!; turn 177; cmd: bw 12 10
# [WARN] (match_VXnXUZ6Lfubb) - turn 177; Unit u_98 collided when trying to move s to (3, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 177; Unit u_41 collided when trying to move n to (13, 11)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 178; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 178; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 178; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 178; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (5, 1) but unit cap reached. Build more CityTiles!; turn 178; cmd: bw 5 1
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (5, 2) but unit cap reached. Build more CityTiles!; turn 178; cmd: bw 5 2
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (12, 10) but unit cap reached. Build more CityTiles!; turn 178; cmd: bw 12 10
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (13, 11) but unit cap reached. Build more CityTiles!; turn 178; cmd: bw 13 11
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (15, 5) but unit cap reached. Build more CityTiles!; turn 178; cmd: bw 15 5
# [WARN] (match_VXnXUZ6Lfubb) - turn 178; Unit u_91 collided when trying to move s to (3, 6)
# [WARN] (match_VXnXUZ6Lfubb) - turn 178; Unit u_86 collided when trying to move s to (12, 11)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 179; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 179; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 179; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 179; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 179; Unit u_91 collided when trying to move s to (3, 6)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 180; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 180; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 180; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 180; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 180; Unit u_91 collided when trying to move s to (3, 6)
# [WARN] (match_VXnXUZ6Lfubb) - turn 180; Unit u_36 collided when trying to move w to (12, 11)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 181; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 181; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 181; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 181; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (15, 8) but unit cap reached. Build more CityTiles!; turn 181; cmd: bw 15 8
# [WARN] (match_VXnXUZ6Lfubb) - turn 181; Unit u_91 collided when trying to move s to (3, 6)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 182; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 182; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 182; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 182; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 182; Unit u_91 collided when trying to move s to (3, 6)
# [WARN] (match_VXnXUZ6Lfubb) - turn 182; Unit u_93 collided when trying to move e to (3, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 182; Unit u_86 collided when trying to move s to (12, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 182; Unit u_101 collided when trying to move n to (11, 0)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 183; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 183; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 183; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 183; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 183; Unit u_91 collided when trying to move s to (3, 6)
# [WARN] (match_VXnXUZ6Lfubb) - turn 183; Unit u_101 collided when trying to move n to (11, 0)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 184; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 184; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 184; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 184; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (15, 13) but unit cap reached. Build more CityTiles!; turn 184; cmd: bw 15 13
# [WARN] (match_VXnXUZ6Lfubb) - turn 184; Unit u_93 collided when trying to move s to (2, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 184; Unit u_77 collided when trying to move s to (12, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 184; Unit u_101 collided when trying to move n to (11, 0)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 185; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 185; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 185; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 185; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 185; Unit u_93 collided when trying to move s to (2, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 185; Unit u_41 collided when trying to move s to (13, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 185; Unit u_77 collided when trying to move s to (12, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 185; Unit u_101 collided when trying to move n to (11, 0)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (2, 10) but unit cap reached. Build more CityTiles!; turn 186; cmd: bw 2 10
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 186; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 186; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 186; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 186; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 186; Unit u_92 collided when trying to move w to (0, 6)
# [WARN] (match_VXnXUZ6Lfubb) - turn 186; Unit u_98 collided when trying to move s to (3, 6)
# [WARN] (match_VXnXUZ6Lfubb) - turn 186; Unit u_77 collided when trying to move s to (12, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 186; Unit u_101 collided when trying to move n to (11, 0)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 187; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 187; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 187; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 187; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 187; Unit u_98 collided when trying to move s to (3, 6)
# [WARN] (match_VXnXUZ6Lfubb) - turn 187; Unit u_77 collided when trying to move s to (12, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 187; Unit u_89 collided when trying to move s to (13, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 187; Unit u_101 collided when trying to move n to (11, 0)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 188; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 188; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 188; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 188; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 188; Unit u_90 collided when trying to move w to (3, 6)
# [WARN] (match_VXnXUZ6Lfubb) - turn 188; Unit u_29 collided when trying to move s to (15, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 188; Unit u_77 collided when trying to move s to (12, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 188; Unit u_89 collided when trying to move s to (13, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 188; Unit u_101 collided when trying to move n to (11, 0)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 189; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 189; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 189; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 189; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (9, 3) but unit cap reached. Build more CityTiles!; turn 189; cmd: bw 9 3
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (12, 4) but unit cap reached. Build more CityTiles!; turn 189; cmd: bw 12 4
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (5, 1) but unit cap reached. Build more CityTiles!; turn 189; cmd: bw 5 1
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (5, 2) but unit cap reached. Build more CityTiles!; turn 189; cmd: bw 5 2
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (12, 10) but unit cap reached. Build more CityTiles!; turn 189; cmd: bw 12 10
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (13, 11) but unit cap reached. Build more CityTiles!; turn 189; cmd: bw 13 11
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (12, 11) but unit cap reached. Build more CityTiles!; turn 189; cmd: bw 12 11
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (15, 5) but unit cap reached. Build more CityTiles!; turn 189; cmd: bw 15 5
# [WARN] (match_VXnXUZ6Lfubb) - turn 189; Unit u_98 collided when trying to move s to (3, 6)
# [WARN] (match_VXnXUZ6Lfubb) - turn 189; Unit u_89 collided when trying to move s to (13, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 189; Unit u_101 collided when trying to move n to (11, 0)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_30 onto opponent CityTile; turn 190; cmd: m u_30 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_50 onto opponent CityTile; turn 190; cmd: m u_50 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_71 onto opponent CityTile; turn 190; cmd: m u_71 s
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_74 onto opponent CityTile; turn 190; cmd: m u_74 s
# [WARN] (match_VXnXUZ6Lfubb) - turn 190; Unit u_77 collided when trying to move s to (12, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 190; Unit u_89 collided when trying to move s to (13, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 190; Unit u_95 collided when trying to move n to (15, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 190; Unit u_101 collided when trying to move n to (11, 0)
# ...
# [WARN] (match_VXnXUZ6Lfubb) - turn 220; Unit u_82 collided when trying to move e to (1, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 220; Unit u_92 collided when trying to move s to (2, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 220; Unit u_143 collided when trying to move s to (2, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 220; Unit u_147 collided when trying to move s to (12, 5)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_136 onto opponent CityTile; turn 221; cmd: m u_136 w
# [WARN] (match_VXnXUZ6Lfubb) - turn 221; Unit u_92 collided when trying to move s to (2, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 221; Unit u_148 collided when trying to move s to (3, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 221; Unit u_147 collided when trying to move s to (12, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 222; Unit u_92 collided when trying to move s to (2, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 222; Unit u_138 collided when trying to move w to (10, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 222; Unit u_146 collided when trying to move s to (12, 6)
# [WARN] (match_VXnXUZ6Lfubb) - turn 222; Unit u_147 collided when trying to move s to (12, 5)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (0, 2) but unit cap reached. Build more CityTiles!; turn 223; cmd: bw 0 2
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (0, 5) but unit cap reached. Build more CityTiles!; turn 223; cmd: bw 0 5
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (1, 6) but unit cap reached. Build more CityTiles!; turn 223; cmd: bw 1 6
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (2, 11) but unit cap reached. Build more CityTiles!; turn 223; cmd: bw 2 11
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (4, 11) but unit cap reached. Build more CityTiles!; turn 223; cmd: bw 4 11
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to move unit u_136 onto opponent CityTile; turn 223; cmd: m u_136 w
# [WARN] (match_VXnXUZ6Lfubb) - turn 223; Unit u_124 collided when trying to move s to (3, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 223; Unit u_147 collided when trying to move s to (12, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 224; Unit u_92 collided when trying to move s to (2, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 224; Unit u_147 collided when trying to move s to (12, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 225; Unit u_142 collided when trying to move s to (3, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 225; Unit u_147 collided when trying to move s to (12, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 226; Unit u_80 collided when trying to move s to (2, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 226; Unit u_139 collided when trying to move s to (3, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 226; Unit u_39 collided when trying to move w to (12, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 226; Unit u_147 collided when trying to move s to (12, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 227; Unit u_148 collided when trying to move s to (3, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 227; Unit u_147 collided when trying to move s to (12, 5)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (15, 5) but unit cap reached. Build more CityTiles!; turn 228; cmd: bw 15 5
# [WARN] (match_VXnXUZ6Lfubb) - turn 228; Unit u_92 collided when trying to move s to (2, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 228; Unit u_142 collided when trying to move s to (3, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 228; Unit u_148 collided when trying to move s to (3, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 228; Unit u_144 collided when trying to move s to (3, 4)
# [WARN] (match_VXnXUZ6Lfubb) - turn 228; Unit u_102 collided when trying to move s to (12, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 228; Unit u_147 collided when trying to move s to (12, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 229; Unit u_142 collided when trying to move s to (3, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 229; Unit u_148 collided when trying to move s to (3, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 229; Unit u_138 collided when trying to move s to (10, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 229; Unit u_147 collided when trying to move s to (12, 5)
# [WARN] (match_VXnXUZ6Lfubb) - turn 230; Unit u_80 collided when trying to move s to (2, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 230; Unit u_142 collided when trying to move s to (3, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 230; Unit u_124 collided when trying to move n to (3, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 230; Unit u_142 collided when trying to move s to (3, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 230; Unit u_136 collided when trying to move w to (3, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 230; Unit u_136 collided when trying to move w to (3, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 230; Unit u_41 collided when trying to move s to (12, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 231; Unit u_142 collided when trying to move s to (3, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 231; Unit u_124 collided when trying to move n to (3, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 231; Unit u_142 collided when trying to move s to (3, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 231; Unit u_136 collided when trying to move w to (3, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 231; Unit u_136 collided when trying to move w to (3, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 232; Unit u_92 collided when trying to move s to (2, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 233; Unit u_92 collided when trying to move s to (2, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 233; Unit u_148 collided when trying to move s to (3, 11)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (2, 11) but unit cap reached. Build more CityTiles!; turn 234; cmd: bw 2 11
# [WARN] (match_VXnXUZ6Lfubb) - turn 234; Unit u_92 collided when trying to move s to (2, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 234; Unit u_148 collided when trying to move s to (3, 11)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (3, 10) but unit cap reached. Build more CityTiles!; turn 235; cmd: bw 3 10
# [WARN] (match_VXnXUZ6Lfubb) - Agent 0 tried to build unit on tile (2, 11) but unit cap reached. Build more CityTiles!; turn 235; cmd: bw 2 11
# [WARN] (match_VXnXUZ6Lfubb) - turn 235; Unit u_148 collided when trying to move s to (3, 11)
# [WARN] (match_VXnXUZ6Lfubb) - turn 242; Unit u_171 collided when trying to move s to (12, 12)
# [WARN] (match_VXnXUZ6Lfubb) - turn 243; Unit u_174 collided when trying to move s to (13, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 245; Unit u_172 collided when trying to move s to (13, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 247; Unit u_174 collided when trying to move s to (13, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 249; Unit u_172 collided when trying to move s to (13, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 251; Unit u_80 collided when trying to move s to (1, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 251; Unit u_174 collided when trying to move s to (13, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 253; Unit u_175 collided when trying to move s to (1, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 253; Unit u_172 collided when trying to move s to (13, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 255; Unit u_80 collided when trying to move s to (1, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 255; Unit u_174 collided when trying to move s to (13, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 257; Unit u_175 collided when trying to move s to (1, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 257; Unit u_172 collided when trying to move s to (13, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 259; Unit u_80 collided when trying to move s to (1, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 259; Unit u_174 collided when trying to move s to (13, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 261; Unit u_175 collided when trying to move s to (1, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 261; Unit u_172 collided when trying to move s to (13, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 263; Unit u_80 collided when trying to move s to (1, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 265; Unit u_174 collided when trying to move n to (13, 9)
# [WARN] (match_VXnXUZ6Lfubb) - turn 266; Unit u_179 collided when trying to move s to (1, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 267; Unit u_176 collided when trying to move n to (13, 9)
# [WARN] (match_VXnXUZ6Lfubb) - turn 275; Unit u_142 collided when trying to move n to (3, 13)
# [WARN] (match_VXnXUZ6Lfubb) - turn 282; Unit u_193 collided when trying to move n to (12, 9)
# [WARN] (match_VXnXUZ6Lfubb) - Agent 1 tried to build unit on tile (15, 8) but unit cap reached. Build more CityTiles!; turn 283; cmd: bw 15 8
# [WARN] (match_VXnXUZ6Lfubb) - turn 287; Unit u_192 collided when trying to move n to (13, 9)
# [WARN] (match_VXnXUZ6Lfubb) - turn 301; Unit u_193 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 302; Unit u_195 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 302; Unit u_193 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 303; Unit u_195 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 303; Unit u_193 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 304; Unit u_193 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 304; Unit u_196 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 304; Unit u_192 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 305; Unit u_196 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 305; Unit u_192 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 306; Unit u_190 collided when trying to move n to (4, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 306; Unit u_196 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 306; Unit u_192 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 307; Unit u_196 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 307; Unit u_192 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 308; Unit u_198 collided when trying to move w to (0, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 308; Unit u_196 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 308; Unit u_192 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 309; Unit u_196 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 309; Unit u_192 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 310; Unit u_196 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 310; Unit u_192 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 322; Unit u_211 collided when trying to move n to (12, 9)
# [WARN] (match_VXnXUZ6Lfubb) - turn 330; Unit u_212 collided when trying to move n to (13, 7)
# [WARN] (match_VXnXUZ6Lfubb) - turn 330; Unit u_210 collided when trying to move n to (13, 8)
# [WARN] (match_VXnXUZ6Lfubb) - turn 334; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 335; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 336; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 338; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 339; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 340; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 340; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 341; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 341; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 341; Unit u_211 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 342; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 342; Unit u_211 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 343; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 343; Unit u_211 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 344; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 344; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 344; Unit u_211 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 345; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 345; Unit u_211 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 345; Unit u_212 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 345; Unit u_210 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 346; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 346; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 346; Unit u_211 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 346; Unit u_212 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 346; Unit u_210 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 347; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 347; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 347; Unit u_211 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 347; Unit u_212 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 347; Unit u_210 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 348; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 348; Unit u_211 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 348; Unit u_212 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 348; Unit u_210 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 349; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 349; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 349; Unit u_211 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 349; Unit u_212 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 349; Unit u_210 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 350; Unit u_208 collided when trying to move n to (1, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 350; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 350; Unit u_211 collided when trying to move n to (12, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 350; Unit u_212 collided when trying to move n to (13, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 350; Unit u_210 collided when trying to move n to (13, 1)
# [WARN] (match_VXnXUZ6Lfubb) - turn 351; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 352; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 353; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 354; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 355; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 356; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 357; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 358; Unit u_203 collided when trying to move n to (15, 0)
# [WARN] (match_VXnXUZ6Lfubb) - turn 359; Unit u_203 collided when trying to move n to (15, 0)

# %%
# Render the match
env.render(mode="ipython", width=1200, height=800)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;715ec6d4-2301-11ec-b411-0242ac130202&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 5621242,
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
#       &quot;action&quot;: {
#         &quot;description&quot;: &quot;Actions&quot;,
#         &quot;type&quot;: &quot;array&quot;,
#         &quot;default&quot;: 0
#       },
#       &quot;agents&quot;: [
#         2
#       ],
#       &quot;configuration&quot;: {
#         &quot;episodeSteps&quot;: {
#           &quot;description&quot;: &quot;Maximum number of steps the environment can run. Total is this number -1. One complete game is 360 steps&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;minimum&quot;: 2,
#           &quot;default&quot;: 361
#         },
#         &quot;actTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) to obtain an action from an agent.&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 3
#         },
#         &quot;runTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) of an episode (not necessarily DONE).&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 1200
#         },
#         &quot;parameters&quot;: {
#           &quot;description&quot;: &quot;Parameters for Lux AI 2021&quot;,
#           &quot;type&quot;: &quot;object&quot;
#         },
#         &quot;mapType&quot;: {
#           &quot;description&quot;: &quot;Map type to use&quot;,
#           &quot;type&quot;: &quot;string&quot;,
#           &quot;default&quot;: &quot;random&quot;
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;Width of map to generate&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;seed&quot;: {
#           &quot;description&quot;: &quot;Seed to use for episodes&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;annotations&quot;: {
#           &quot;description&quot;: &quot;Whether to enable debug annotations or not.&quot;,
#           &quot;type&quot;: &quot;boolean&quot;,
#           &quot;default&quot;: false
#         },
#         &quot;loglevel&quot;: {
#           &quot;description&quot;: &quot;Logging level of the game. 2 for warnings (e.g unit collisions, malformed actions), 1 for errors, 0 for none&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         }
#       },
#       &quot;info&quot;: {},
#       &quot;observation&quot;: {
#         &quot;remainingOverageTime&quot;: {
#           &quot;description&quot;: &quot;Total remaining banked time (seconds) that can be used in excess of per-step actTimeouts -- agent is disqualified with TIMEOUT status when this drops below 0.&quot;,
#           &quot;shared&quot;: false,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 60
#         },
#         &quot;step&quot;: {
#           &quot;description&quot;: &quot;Current step within the episode.&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 0
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;The width of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;height&quot;: {
#           &quot;description&quot;: &quot;The height of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;reward&quot;: {
#           &quot;description&quot;: &quot;Current reward of the agent. Equal to number of city tiles * 10000 + number of units&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         },
#         &quot;updates&quot;: {
#           &quot;description&quot;: &quot;List of update strings for agents to use and generate the observed state&quot;,
#           &quot;type&quot;: &quot;array&quot;,
#           &quot;shared&quot;: true
#         },
#         &quot;globalUnitIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;globalCityIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;player&quot;: {
#           &quot;description&quot;: &quot;Current player's index / team id&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;defaults&quot;: [
#             0,
#             1
#           ]
#         }
#       },
#       &quot;reward&quot;: {
#         &quot;description&quot;: &quot;Reward of the agent. Equal to number of city tiles * 1000 + number of units&quot;,
#         &quot;type&quot;: [
#           &quot;integer&quot;,
#           &quot;null&quot;
#         ],
#         &quot;default&quot;: 0
#       }
#     },
#     &quot;steps&quot;: [
#       [
#         {
#           &quot;action&quot;: [],
#           &quot;reward&quot;: 0,
#           &quot;info&quot;: {},
#           &quot;observation&quot;: {
#             &quot;remainingOverageTime&quot;: 60,
#             &quot;step&quot;: 0,
#             &quot;width&quot;: 16,
#             &quot;height&quot;: 16,
#             &quot;reward&quot;: 0,
#             &quot;globalUnitIDCount&quot;: 2,
#             &quot;globalCityIDCount&quot;: 2,
#             &quot;player&quot;: 0,
#             &quot;updates&quot;: [
#               &quot;0&quot;,
#               &quot;16 16&quot;,
#               &quot;rp 0 0&quot;,
#               &quot;rp 1 0&quot;,
#               &quot;r wood 0 3 800&quot;,
#               &quot;r wood 0 4 800&quot;,
#               &quot;r coal 0 6 405&quot;,
#               &quot;r coal 0 7 368&quot;,
#               &quot;r uranium 0 15 338&quot;,
#               &quot;r wood 1 4 800&quot;,
#               &quot;r wood 1 13 349&quot;,
#               &quot;r wood 2 11 354&quot;,
#               &quot;r wood 2 12 368&quot;,
#               &quot;r wood 3 3 374&quot;,
#               &quot;r wood 3 11 381&quot;,
#               &quot;r wood 3 12 376&quot;,
#               &quot;r wood 4 2 337&quot;,
#               &quot;r wood 4 3 391&quot;,
#               &quot;r wood 5 2 393&quot;,
#               &quot;r wood 5 3 375&quot;,
#               &quot;r coal 7 15 391&quot;,
#               &quot;r coal 8 15 391&quot;,
#               &quot;r wood 10 2 393&quot;,
#               &quot;r wood 10 3 375&quot;,
#               &quot;r wood 11 2 337&quot;,
#               &quot;r wood 11 3 391&quot;,
#               &quot;r wood 12 3 374&quot;,
#               &quot;r wood 12 11 381&quot;,
#               &quot;r wood 12 12 376&quot;,
#               &quot;r wood 13 11 354&quot;,
#               &quot;r wood 13 12 368&quot;,
#               &quot;r wood 14 4 800&quot;,
#               &quot;r wood 14 13 349&quot;,

# %% [markdown]
# # Prepare and submit the kaggle submission

# %%
# !tar -czf submission.tar.gz -C kaggle_submissions .
# !ls
# Out:
# __notebook__.ipynb  agent_policy.py	log.txt		 models
# __pycache__	    kaggle_submissions	lux_tensorboard  submission.tar.gz
